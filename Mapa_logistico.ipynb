# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def mapa_logistico(r,x,n):
    f_x = [x]
    for i in range(n):
        x = r*x*(1-x)
        f_x.append(x)
    return f_x

# %%
def pontos_fixos(f_x):
    # Cria um vetor com 4 digitos decimais a partir do mapa logistico
    f_xV = np.round(np.array(f_x),4)
    
    # Encontra os valores unicos e conta as recorrências
    valores_unicos, reco = np.unique(f_xV, return_counts=True)
    
    # Filtra os valores repetidos
    repetidos = valores_unicos[reco > 1]
    
    return repetidos

# %%
r = 0.5
x0 = 0.1
n = 100
y = mapa_logistico(r,x0,n)
pontos = pontos_fixos(y)

plt.figure(figsize = (10,4))
plt.plot(y, marker = 'o', color = 'b')
plt.title(f'Mapa Logístico com taxa r = {r} e população inicial x0 = {x0}')
plt.ylabel('População Reduzida')
plt.xlabel('Tempo Discreto')

legenda = [f'Ponto Fixo: {pontos}']
plt.legend(handles=[plt.Line2D([], [], linestyle='None', label=legenda[0])], loc='upper right')

plt.show()

# %%
r = 1.5
x0 = 0.1
n = 100
y = mapa_logistico(r,x0,n)
ponto = pontos_fixos(y)

plt.figure(figsize = (10,4))
plt.plot(y, marker = 'o', color = 'b')
plt.title(f'Mapa Logístico com taxa r = {r} e população inicial x0 = {x0}')
plt.ylabel('População Reduzida')
plt.xlabel('Tempo Discreto')

legenda = [f'Ponto Fixo: {pontos}']
plt.legend(handles=[plt.Line2D([], [], linestyle='None', label=legenda[0])], loc='lower right')

plt.show()

# %%
r = 2.5
x0 = 0.1
n = 100
y = mapa_logistico(r,x0,n)
pontos = pontos_fixos(y)

plt.figure(figsize = (12,2))
plt.plot(y, marker = 'o', color = 'b')
plt.title(f'Mapa Logístico com taxa r = {r} e população inicial x0 = {x0}')
plt.ylabel('População Reduzida')
plt.xlabel('Tempo Discreto')

legenda = [f'Ponto Fixo: {pontos_fixos}']
plt.legend(handles = [plt.Line2D([],[], linestyle = 'None', label = legenda[0])], loc = 'lower right')

plt.show()

# %%
r = 3.3
x0 = 0.1
n = 100
y = mapa_logistico(r,x0,n)
pontos = 

plt.figure(figsize = (10,4))
plt.plot(y, marker = 'o', color = 'b')
plt.title(f'Mapa Logístico com taxa r = {r} e população inicial x0 = {x0}')
plt.ylabel('População Reduzida')
plt.xlabel('Tempo Discreto')
plt.show()
# Out:
#   File "C:\Users\alan_physicist\AppData\Local\Temp\ipykernel_8408\2185871248.py", line 5
#     pontos =
#              ^
# SyntaxError: invalid syntax

# %%
r = 3.5
x0 = 0.1
n = 100
y = mapa_logistico(r,x0,n)


plt.figure(figsize = (10,4))
plt.plot(y, marker = 'o', color = 'b')
plt.title(f'Mapa Logístico com taxa r = {r} e população inicial x0 = {x0}')
plt.ylabel('População Reduzida')
plt.xlabel('Tempo Discreto')
plt.show()

# %%
r = 3.6
x0 = 0.1
n = 100
y = mapa_logistico(r,x0,n)

plt.figure(figsize = (10,4))
plt.plot(y, marker = 'o', color = 'b' )
plt.title(f'Mapa Logístico com taxa r = {r} e população inicial x0 = {x0}')
plt.ylabel('População Reduzida')
plt.xlabel('Tempo Discreto')


legenda = [f'Pontos Fixos: {pontos_fixos}']
plt.legend(handles=[plt.Line2D([], [], linestyle='None', label=legenda[0])], loc='lower right')

plt.show()
